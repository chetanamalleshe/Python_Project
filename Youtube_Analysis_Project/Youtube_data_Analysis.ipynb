# %% [markdown]
# ### Exploratory Data Analysis on YouTube data.

# %% [markdown]
# ### Q1. Import required libraries and read the provided dataset (youtube_dislike_dataset.csv) and retrieve top 5 and bottom 5 records.

# %%
#importing required libraries
import pandas as pd

# %%
# reading the provided dataset

df=pd.read_csv("youtube_dislike_dataset.csv")

# %%
df
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title         published_at  \
# ...

# %%
# Retrieving top 5 records.
df.head()
# Out:
#       video_id                                       title  \
# 0  --0bCF-iK2E        Jadon Sancho  Magical Skills & Goals
# 1  --14w5SOEUs          Migos - Avalanche (Official Video)
# 2  --40TEbZ9Is  Supporting Actress in a Comedy: 73rd Emmys
# 3  --4tfbSyYDE     JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4  --DKkzWVh-E                Why Retaining Walls Collapse
#
#                  channel_id          channel_title         published_at  \
# 0  UC6UL29enLNe4mqwTfAyeNuw             Bundesliga  2021-07-01 10:00:00
# 1  UCGIelM2Dj3zza3xyV3pL3WQ              MigosVEVO  2021-06-10 16:00:00
# 2  UClBKH8yZRcM4AsRjDVEdjMg     Television Academy  2021-09-20 01:03:32
# 3  UCsmXiDP8S40uBeJYxvyulmA                    JO1  2021-03-03 10:00:17
# 4  UCMOqf8ab-42UUQIdVoKwjlQ  Practical Engineering  2021-12-07 13:00:00
#
#    view_count   likes  dislikes  comment_count  \
# 0     1048888   19515       226           1319
# 1    15352638  359277      7479          18729
# ...

# %%
# Retrieving bottom 5 records.
df.tail()
# Out:
#           video_id                                              title  \
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id      channel_title         published_at  \
# 37417  UCEB4a5o_6KfjxHwNMnmj54Q           Lil Tjay  2021-02-12 05:03:49
# 37418  UCWJ2lWNubArHWmf3FIHbfcQ                NBA  2021-01-16 05:39:05
# 37419  UCuhAUMLzJxlP1W7mEk0_6lA            MAMAMOO  2021-06-02 09:00:10
# 37420  UC8NjnNWMsRqq11NYvHAQb1g     Master Podcast  2020-10-20 20:59:30
# 37421  UCEg25rdRZXg32iwai6N6l0w  Tottenham Hotspur  2021-05-23 21:00:31
#
#        view_count    likes  dislikes  comment_count  \
# 37417   120408275  2180780     35871          81360
# ...

# %% [markdown]
# ### Q2. Check the info of the dataframe and write your inferences on data types and shape of the dataset.

# %%
print("Info of the dataset:")
print(df.info())

print("Shape of the dataset:")
print(df.shape)

print("Data types of the dataset:")
print(df.dtypes)
# Out:
# Info of the dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37422 entries, 0 to 37421
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   video_id       37422 non-null  object
#  1   title          37422 non-null  object
#  2   channel_id     37422 non-null  object
#  3   channel_title  37422 non-null  object
#  4   published_at   37422 non-null  object
#  5   view_count     37422 non-null  int64
#  6   likes          37422 non-null  int64
#  7   dislikes       37422 non-null  int64
#  8   comment_count  37422 non-null  int64
#  9   tags           37422 non-null  object
#  10  description    37422 non-null  object
#  11  comments       37264 non-null  object
# dtypes: int64(4), object(8)
# memory usage: 3.4+ MB
# None
# Shape of the dataset:
# (37422, 12)
# Data types of the dataset:
# video_id         object
# title            object
# channel_id       object
# channel_title    object
# ...

# %% [markdown]
# #### inferences on data types and shape of the dataset:
#
# - The above dataframe is of object datatype.These Data types suggest that the dataset contains textual and numerical data,used for columns containing text, and int64 data type used for columns containing numerical values.There are 4 columns with data type int64 and 8 columns with data type object.
# - It consists of 37422 rows and 12 columns.
# - Every row represents the data about a video published on youtube.
# - The dataset seems to be relatively large in terms of memory usage,occupying approximately 3.4+ MB of memory.
# - There are no missing values in most columns,except for the "comments" column, which has some missing values(37264 non-null entries out of 37422 total entries).

# %% [markdown]
# ### Q3. Check for the Percentage of the missing values and drop or impute them.

# %%
data=df.isnull()
print(data)
data.mean()*100
# Out:
#        video_id  title  channel_id  channel_title  published_at  view_count  \
# 0         False  False       False          False         False       False
# 1         False  False       False          False         False       False
# 2         False  False       False          False         False       False
# 3         False  False       False          False         False       False
# 4         False  False       False          False         False       False
# ...         ...    ...         ...            ...           ...         ...
# 37417     False  False       False          False         False       False
# 37418     False  False       False          False         False       False
# 37419     False  False       False          False         False       False
# 37420     False  False       False          False         False       False
# 37421     False  False       False          False         False       False
#
# ...

# %%
# Dropping comments column
df.drop(columns=['comments'],inplace=True)  # The comments column is dropped

# %% [markdown]
# ### Q4. Check the statistical summary of both numerical and categorical columns and write your inferences.

# %%
# Statistical summary of numerical columns
df.describe()
# Out:
#          view_count         likes      dislikes  comment_count
# count  3.742200e+04  3.742200e+04  3.742200e+04   3.742200e+04
# mean   5.697838e+06  1.668147e+05  4.989862e+03   9.924930e+03
# std    2.426622e+07  5.375670e+05  3.070824e+04   1.171003e+05
# min    2.036800e+04  0.000000e+00  0.000000e+00   0.000000e+00
# 25%    5.122970e+05  1.323350e+04  2.810000e+02   9.000000e+02
# 50%    1.319078e+06  4.233050e+04  7.960000e+02   2.328000e+03
# 75%    3.670231e+06  1.304698e+05  2.461750e+03   6.184000e+03
# max    1.322797e+09  3.183768e+07  2.397733e+06   1.607103e+07

# %%
# Statistics summary of categorical columns
df.describe(include= ["object"])
# Out:
#            video_id  title                channel_id        channel_title  \
# count         37422  37422                     37422                37422
# unique        37422  37113                     10961                10883
# top     --0bCF-iK2E    www  UCNAf1k0yIjyGu3k9BwAg3lg  Sky Sports Football
# freq              1     21                       533                  533
#
#                published_at   tags description
# count                 37422  37422       37422
# unique                36772  28799       35630
# top     2020-10-16 04:00:10
# freq                      6   3817         589

# %% [markdown]
# ### Inferences

# %% [markdown]
# From the statistics summary of numerical columns,It observed that,
# 1) View count:
# The average number of views is approximately 5.7 million.
# The minimum number of views for a video is about 20,368,which means some videos have relatively few views & 25% of the videos have fewer than 512,297 views.
# The maximum view count is approximately 1.32 billion,showing that there are videos with very high view counts.
# The data has a wide range with a standard deviation of approximately 24.3 million.
# 2) Likes:
# The average number of likes is about 166,814.
# some videos have zero likes,which suggests that some videos have no likes.
# 25% of the videos have fewer than 13,233 likes.
# The maximum number of likes is approximately 31.8 million.
# The data has relatively high standard deviation,indicating variablity in the number of likes.
# 3) Dislikes:
# The average number of dislikes is approximately 4,990,suggesting a moderate number of dislikes on average.
# Some videos have zero dislikes ,as the minimum value is zero.
# 25% of the videos have fewer than 281 dislikes.
# The maximum number of dislikes is approximately 2.4 million.
# The data has relatively high standard deviation,indicating variablity in the number of dislikes.
# 4) Comment Count:
# The average number of comments is about 9,925.
# The minimum number of comments is 0,suggesting that some videos have no comments.
# 25% of the videos have fewer than 900 comments.
# The maximum number of comments is approximately 16.1 million.
# The comment counts also exhibit a high standard deviation of around 117,100,indicating significant variability in the number of comments.
#
# Whereas the Categorical column provides us with a good understanding of the dataset,
#
# - count:
#  The count for all numerical columns is 37,422, which means there are 37,422 data points in each of these columns.
#
# -  video id :
# There are 37,422 unique values in this column, which suggests that each video has a unique identifier.
# The most frequently occurring value in this column is "--0bCF-iK2E."
# The value "--0bCF-iK2E" occurs only once,indicating that most video IDs are unique.
#
#
# - title :
# There are 37,113 unique values in the "title" column.
# The most frequently occurring title is "www."
# The title "www" appears 21 times, indicating that it is a common title but not unique.
#
# - channel_id :
# There are 10,961 unique values in the "channel_id" column.
# The most frequently occurring channel ID is "UCNAf1k0yIjyGu3k9BwAg3lg."
# The channel ID "UCNAf1k0yIjyGu3k9BwAg3lg" appears 533 times.
#
# - channel_title :
# There are 10,883 unique values in the "channel_title" column.
# The most frequently occurring channel title is "Sky Sports Football."
# The channel title "Sky Sports Football" also appears 533 times.
#
# - published_at :
# There are 36,772 unique values in the "published_at" column.
# The most frequently occurring publication date is "2020-10-16 04:00:10".
# This date appears six times.
#
# - tags :
# There are 28,799 unique values in the "tags" column.
# The most frequently occurring tag is not provided in the summary.
# The most frequent tag appears 3,817 times, but the specific tag is not mentioned in the summary.
#
# - description :
# There are 35,630 unique values in the "description" column.
# The most frequently occurring description is not provided in the summary.
# The most frequent description appears 589 times, but the specific description is not mentioned in the summary.

# %% [markdown]
# ### Q5.Convert datatype of column published_at from object to pandas datetime.

# %%
df["published_at"]= pd.to_datetime(df["published_at"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37422 entries, 0 to 37421
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   video_id       37422 non-null  object
#  1   title          37422 non-null  object
#  2   channel_id     37422 non-null  object
#  3   channel_title  37422 non-null  object
#  4   published_at   37422 non-null  datetime64[ns]
#  5   view_count     37422 non-null  int64
#  6   likes          37422 non-null  int64
#  7   dislikes       37422 non-null  int64
#  8   comment_count  37422 non-null  int64
#  9   tags           37422 non-null  object
#  10  description    37422 non-null  object
# dtypes: datetime64[ns](1), int64(4), object(6)
# memory usage: 3.1+ MB

# %% [markdown]
# ### Q6. Create a new column as 'published_month' using the column published_at (display the months only)

# %%
df["published_at"]
# Out:
# 0       2021-07-01 10:00:00
# 1       2021-06-10 16:00:00
# 2       2021-09-20 01:03:32
# 3       2021-03-03 10:00:17
# 4       2021-12-07 13:00:00
#                 ...
# 37417   2021-02-12 05:03:49
# 37418   2021-01-16 05:39:05
# 37419   2021-06-02 09:00:10
# 37420   2020-10-20 20:59:30
# 37421   2021-05-23 21:00:31
# Name: published_at, Length: 37422, dtype: datetime64[ns]

# %%
df["published_month"]=df["published_at"].dt.month
df
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title        published_at  \
# ...

# %% [markdown]
# ### Q7. Replace the numbers in the column published_month as names of the months i,e., 1 as 'Jan', 2 as 'Feb'and so on.....

# %%
df["published_month"]= df["published_at"].dt.strftime('%b')
df
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title        published_at  \
# ...

# %% [markdown]
# ### Q8. Find the number of videos published each month and arrange the months in a decreasing order based on the video count.

# %%
MonthlyPublished_video= df.groupby("published_month")['video_id'].count()
MonthlyPublished_video
MonthlyPublished_video.sort_values(ascending=False)
# Out:
# published_month
# Oct    4991
# Sep    4880
# Nov    4851
# Aug    4262
# Dec    3072
# Jul    2340
# Jun    2316
# Mar    2258
# Feb    2137
# Apr    2126
# Jan    2108
# May    2081
# Name: video_id, dtype: int64

# %% [markdown]
# ### Q9. Find the count of unique video_id, channel_id and channel_title.

# %%
#Count of unique video_id
Count_uniquevideo_id=df["video_id"].nunique()
print(f"Count of unique video_id is {Count_uniquevideo_id}")
# Out:
# Count of unique video_id is 37422

# %%
#Count of unique channel_id
Count_uniquechannel_id=df["channel_id"].nunique()
print(f"Count of unique channel_id is {Count_uniquechannel_id}")
# Out:
# Count of unique channel_id is 10961

# %%
#Count of unique channel_title
Count_uniquechannel_title=df["channel_title"].nunique()
print(f"Count of unique channel_title is {Count_uniquechannel_title}")
# Out:
# Count of unique channel_title is 10883

# %% [markdown]
# ### 10. Find the top10 channel names having the highest number of videos in the dataset and the bottom10 having lowest number of videos.

# %%
# The top10 channel names having the highest number of videos in the dataset
top10_channel=df.groupby(["channel_title"])["title"].count().sort_values(ascending=False).head(10)
print(f"Top 10 channel names is : {top10_channel}")
# Out:
# Top 10 channel names is : channel_title
# Sky Sports Football    533
# The United Stand       301
# BT Sport               246
# NBA                    209
# NFL                    162
# WWE                    122
# SSSniperWolf            99
# SSundee                 98
# FORMULA 1               87
# NHL                     86
# Name: title, dtype: int64

# %%
# The bottom10 channel names having the lowest number of videos in the dataset
bottom10_channel= df.groupby(["channel_title"])["title"].count().sort_values(ascending=True).head(10)
print(f"Bottom 10 channel names is : {bottom10_channel}")
# Out:
# Bottom 10 channel names is : channel_title
#    SilverName                   1
# Mini Muka                       1
# Mini Ladd                       1
# MindYourLogic                   1
# Mind Body Tonic With Dr Sita    1
# Mimi Ar                         1
# Millyz                          1
# Milkair                         1
# Milissa Grande                  1
# MikuruSong                      1
# Name: title, dtype: int64

# %% [markdown]
# ### 11. Find the title of the video which has the maximum number of likes and the title of the video having minimum likes and write your inferences.

# %%
# The title of the video which has the maximum number of likes
maxLikes=df["likes"].max()
maxLikes_title=df[df["likes"]== maxLikes]['title'].values[0]
print(f"The title of the video which has the maximum likes is: {maxLikes_title}")
# Out:
# The title of the video which has the maximum likes is: BTS () 'Dynamite' Official MV

# %%
# The title of the video which has the minimum number of likes
minLikes=df["likes"].min()
minLikes_title=df[df["likes"]== minLikes]['title'].values[0]
print(f"The title of the video which has the minimum likes is: {minLikes_title}")
# Out:
# The title of the video which has the minimum likes is: Kim Kardashian's Must-See Moments on "Saturday Night Live" | E! News

# %% [markdown]
# ### Inferences:

# %% [markdown]
# - "BTS 'Dynamite' Official MV" is the most liked video in the dataset.This suggests that the video is exceptionally popular.
# - "Kim Kardashian's Must-See Moments on 'Saturday Night Live' | E! News" has the minimum number of likes, indicating that it may not have received as much attention compared to other videos in the dataset.

# %% [markdown]
# ### 12. Find the title of the video which has the maximum number of dislikes and the title of the video having minimum dislikes and write your inferences.

# %%
# The title of the video which has the maximum number of dislikes
maxDislikes=df["dislikes"].max()
maxDislikes_title=df[df["dislikes"]== maxDislikes]['title'].values[0]
print(f"The title of the video which has the maximum dislikes is: {maxDislikes_title}")
# Out:
# The title of the video which has the maximum dislikes is: Cuties | Official Trailer | Netflix

# %%
# The title of the video which has the minimum number of dislikes
minDislikes=df["dislikes"].min()
minDislikes_title=df[df["dislikes"]== minDislikes]['title'].values[0]
print(f"The title of the video which has the minimum dislikes is: {minDislikes_title}")
# Out:
# The title of the video which has the minimum dislikes is: Kim Kardashian's Must-See Moments on "Saturday Night Live" | E! News

# %% [markdown]
# ### Inferences:

# %% [markdown]
# - "Cuties | Official Trailer | Netflix" has the maximum number of dislikes, which suggests that this video might have generated a lot of controversy,possibly due to its content or the way it was marketed.
# - "Kim Kardashian's Must-See Moments on 'Saturday Night Live' | E! News" has the minimum number of dislikes, indicating that this video was relatively well-received by the audience.
# - It can also be observed by viewing kim Kardashian video in both the questions is the least liked and disliked video.

# %% [markdown]
# ### 13. Does the number of views have any effect on how many people disliked the video? Support your answer with a metric and a plot.

# %%
correlation = df["view_count"].corr(df["dislikes"])
correlation
# Out:
# 0.6844687753905547

# %%
#creating Scatter plot
import matplotlib.pyplot as plot

# %%
X = df["view_count"]
Y = df["dislikes"]
plot.scatter(X,Y,c= 'green')
plot.xlabel("Views")
plot.ylabel("Dislikes")
plot.title("Correlation between Views and Dislikes")
plot.show()

# %% [markdown]
# ### Inferences

# %% [markdown]
# - The correlation between views and dislikes is 0.684.
# Suggests a positive correlation between the number of views and the number of dislikes on a video.
# - This means that as the view count increases, the number of dislikes tends to increase as well.
# and other factors may influence the number of dislikes on a video, such as the video's content,quality etc.

# %% [markdown]
# ### 14. Display all the information about the videos that were published in January, and mention the count of videos that were published in January.

# %%
df['published_at']=pd.to_datetime(df['published_at'])
df['published_month']=df['published_at'].dt.month
videos_inJan=df[df['published_month']==1]
videos_inJan
# Out:
#           video_id                                              title  \
# 27     -2Gwm7QfBnE                                    Q&A With Naisha
# 48     -4sfXSHSxzA           SURPRISING BRENT WITH HIS TIKTOK CRUSH!!
# 95     -AJD1Fc5rpQ  WE ARE HAVING A BABY! | finding out i'm pregna...
# 103    -AuJiwjsmWk              Do Ugly Foods Taste Worse? Taste Test
# 182    -JhqO2KWr5U                                   Schlatt gets fit
# ...            ...                                                ...
# 37300  zmzFL5bG-jc  DEVINE MON PERSONNAGE AVANT AKINATOR ! (c'est ...
# 37329  zpzjex7qwrA  Lampard Sacked Within Days Rorys Misery | Chel...
# 37345  zqyv-B6mnBM                 Lil Wayne - Ain't Got Time (Audio)
# 37383  zwfu1-24T7Q  PRADA Cup Day 1 | Full Race Replay | PRADA Cup...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
#
#                      channel_id       channel_title        published_at  \
# ...

# %%
#summary statistics
print("The descriptive summary of the videos published in January is :")
videos_inJan.describe()
# Out:
# The descriptive summary of the videos published in January is :
#          view_count         likes       dislikes  comment_count  \
# count  2.108000e+03  2.108000e+03    2108.000000   2.108000e+03
# mean   4.976449e+06  1.315030e+05    3614.568311   8.923385e+03
# std    2.055331e+07  3.886887e+05   13946.711333   3.664662e+04
# min    2.845000e+04  2.800000e+01       3.000000   0.000000e+00
# 25%    4.322335e+05  1.032400e+04     249.000000   8.747500e+02
# 50%    1.147500e+06  3.173900e+04     729.000000   2.328500e+03
# 75%    3.227483e+06  1.076512e+05    2243.250000   6.302000e+03
# max    6.203274e+08  7.828036e+06  409144.000000   1.095119e+06
#
#        published_month
# count           2108.0
# mean               1.0
# std                0.0
# min                1.0
# 25%                1.0
# 50%                1.0
# 75%                1.0
# max                1.0

# %%
print("Number of videos published in January:")
videos_inJan.shape[0]
# Out:
# Number of videos published in January:
# 2108
